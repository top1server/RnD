# %%
import numpy as np
import math

sentences = [
    "Mèo là loài động vật có vú.",
    "Chó là bạn tốt của con người.",
    "Mèo và chó đều là thú cưng phổ biến.",
    "Trời hôm nay rất đẹp.",
    "Hôm nay trời mưa.",
    "Tôi thích ăn cơm với cá.",
    "Mèo thường ăn cá.",
    "Chó thích chạy nhảy ngoài trời.",
    "Trời mưa làm ướt mọi thứ.",
    "Cơm là món ăn truyền thống của người Việt."
]

# %%
# Bước 1: Tokenize các câu và xây dựng tập từ vựng
def tokenize(sentence):
    return sentence.lower().split()

vocab = set()
tokenized_sentences = []
for sentence in sentences:
    tokens = tokenize(sentence)
    tokenized_sentences.append(tokens)
    vocab.update(tokens)

vocab = sorted(vocab)
vocab_index = {word: idx for idx, word in enumerate(vocab)}

# %%
# Bước 2: tính toán TF (Term frequency)
def compute_tf(tokens, vocab_index):
    tf = np.zeros(len(vocab_index))
    for word in tokens:
        if word in vocab_index:
            tf[vocab_index[word]] += 1
    tf = tf / len(tokens)
    return tf

tf_matrix = np.array([compute_tf(tokens, vocab_index) for tokens in tokenized_sentences])

# %%
# Bước 3: Tính toán IDF (Inverse Document Frequency)
def compute_idf(tokenized_sentences, vocab_index):
    idf = np.zeros(len(vocab_index))
    total_docs = len(tokenized_sentences)

    for tokens in tokenized_sentences:
        for word in set(tokens): # Đảm bảo mỗi từ chỉ được tính một lần trong mỗi tài liệu
            if word in vocab_index:
                idf[vocab_index[word]] += 1

    idf = np.log((total_docs + 1) / (idf + 1)) + 1 # Thêm 1 để tránh chia cho 0
    return idf

idf_vector = compute_idf(tokenized_sentences, vocab_index)

# %%
# Bước 4: Tính toán TF-IDF
tfidf_matrix = tf_matrix * idf_vector

# Bước 5: Tính toán cosine similarity
def cosine_similarity(v1, v2):
    dot_product = np.dot(v1, v2)
    norm_v1 = np.linalg.norm(v1)
    norm_v2 = np.linalg.norm(v2)
    return dot_product / (norm_v1 * norm_v2)

# Tính ma trận tương đồng
similarity_matrix = np.zeros((len(sentences), len(sentences)))

# %%
for i in range(len(sentences)):
    for j in range(len(sentences)):
        similarity_matrix[i][j] = cosine_similarity(tfidf_matrix[i], tfidf_matrix[j])

# Hiển thị ma trận tương đồng
import pandas as pd
df = pd.DataFrame(similarity_matrix, index=sentences, columns=sentences)

# %%
df
# Out:
#                                             Mèo là loài động vật có vú.  \
# Mèo là loài động vật có vú.                                    1.000000
# Chó là bạn tốt của con người.                                  0.074739
# Mèo và chó đều là thú cưng phổ biến.                           0.147326
# Trời hôm nay rất đẹp.                                          0.000000
# Hôm nay trời mưa.                                              0.000000
# Tôi thích ăn cơm với cá.                                       0.000000
# Mèo thường ăn cá.                                              0.134367
# Chó thích chạy nhảy ngoài trời.                                0.000000
# Trời mưa làm ướt mọi thứ.                                      0.000000
# Cơm là món ăn truyền thống của người Việt.                     0.065511
#
#                                             Chó là bạn tốt của con người.  \
# Mèo là loài động vật có vú.                                      0.074739
# Chó là bạn tốt của con người.                                    1.000000
# Mèo và chó đều là thú cưng phổ biến.                             0.150860
# Trời hôm nay rất đẹp.                                            0.000000
# Hôm nay trời mưa.                                                0.000000
# Tôi thích ăn cơm với cá.                                         0.000000
# Mèo thường ăn cá.                                                0.000000
# Chó thích chạy nhảy ngoài trời.                                  0.100752
# Trời mưa làm ướt mọi thứ.                                        0.000000
# Cơm là món ăn truyền thống của người Việt.                       0.177959
#
#                                             Mèo và chó đều là thú cưng phổ biến.  \
# Mèo là loài động vật có vú.                                             0.147326
# Chó là bạn tốt của con người.                                           0.150860
# Mèo và chó đều là thú cưng phổ biến.                                    1.000000
# Trời hôm nay rất đẹp.                                                   0.000000
# Hôm nay trời mưa.                                                       0.000000
# Tôi thích ăn cơm với cá.                                                0.000000
# Mèo thường ăn cá.                                                       0.119738
# Chó thích chạy nhảy ngoài trời.                                         0.087680
# Trời mưa làm ướt mọi thứ.                                               0.000000
# Cơm là món ăn truyền thống của người Việt.                              0.058379
#
#                                             Trời hôm nay rất đẹp.  \
# Mèo là loài động vật có vú.                              0.000000
# Chó là bạn tốt của con người.                            0.000000
# Mèo và chó đều là thú cưng phổ biến.                     0.000000
# Trời hôm nay rất đẹp.                                    1.000000
# Hôm nay trời mưa.                                        0.577163
# Tôi thích ăn cơm với cá.                                 0.000000
# Mèo thường ăn cá.                                        0.000000
# Chó thích chạy nhảy ngoài trời.                          0.000000
# Trời mưa làm ướt mọi thứ.                                0.117386
# Cơm là món ăn truyền thống của người Việt.               0.000000
#
#                                             Hôm nay trời mưa.  \
# Mèo là loài động vật có vú.                          0.000000
# Chó là bạn tốt của con người.                        0.000000
# Mèo và chó đều là thú cưng phổ biến.                 0.000000
# Trời hôm nay rất đẹp.                                0.577163
# Hôm nay trời mưa.                                    1.000000
# Tôi thích ăn cơm với cá.                             0.000000
# Mèo thường ăn cá.                                    0.000000
# Chó thích chạy nhảy ngoài trời.                      0.000000
# Trời mưa làm ướt mọi thứ.                            0.135554
# Cơm là món ăn truyền thống của người Việt.           0.000000
#
#                                             Tôi thích ăn cơm với cá.  \
# Mèo là loài động vật có vú.                                 0.000000
# Chó là bạn tốt của con người.                               0.000000
# Mèo và chó đều là thú cưng phổ biến.                        0.000000
# Trời hôm nay rất đẹp.                                       0.000000
# Hôm nay trời mưa.                                           0.000000
# Tôi thích ăn cơm với cá.                                    1.000000
# Mèo thường ăn cá.                                           0.349097
# Chó thích chạy nhảy ngoài trời.                             0.144799
# Trời mưa làm ướt mọi thứ.                                   0.000000
# Cơm là món ăn truyền thống của người Việt.                  0.215326
#
#                                             Mèo thường ăn cá.  \
# Mèo là loài động vật có vú.                          0.134367
# Chó là bạn tốt của con người.                        0.000000
# Mèo và chó đều là thú cưng phổ biến.                 0.119738
# Trời hôm nay rất đẹp.                                0.000000
# Hôm nay trời mưa.                                    0.000000
# Tôi thích ăn cơm với cá.                             0.349097
# Mèo thường ăn cá.                                    1.000000
# Chó thích chạy nhảy ngoài trời.                      0.000000
# Trời mưa làm ướt mọi thứ.                            0.000000
# Cơm là món ăn truyền thống của người Việt.           0.120603
#
#                                             Chó thích chạy nhảy ngoài trời.  \
# Mèo là loài động vật có vú.                                        0.000000
# Chó là bạn tốt của con người.                                      0.100752
# Mèo và chó đều là thú cưng phổ biến.                               0.087680
# Trời hôm nay rất đẹp.                                              0.000000
# Hôm nay trời mưa.                                                  0.000000
# Tôi thích ăn cơm với cá.                                           0.144799
# Mèo thường ăn cá.                                                  0.000000
# Chó thích chạy nhảy ngoài trời.                                    1.000000
# Trời mưa làm ướt mọi thứ.                                          0.000000
# Cơm là món ăn truyền thống của người Việt.                         0.000000
#
#                                             Trời mưa làm ướt mọi thứ.  \
# Mèo là loài động vật có vú.                                  0.000000
# Chó là bạn tốt của con người.                                0.000000
# Mèo và chó đều là thú cưng phổ biến.                         0.000000
# Trời hôm nay rất đẹp.                                        0.117386
# Hôm nay trời mưa.                                            0.135554
# Tôi thích ăn cơm với cá.                                     0.000000
# Mèo thường ăn cá.                                            0.000000
# Chó thích chạy nhảy ngoài trời.                              0.000000
# Trời mưa làm ướt mọi thứ.                                    1.000000
# Cơm là món ăn truyền thống của người Việt.                   0.000000
#
#                                             Cơm là món ăn truyền thống của người Việt.
# Mèo là loài động vật có vú.                                                   0.065511
# Chó là bạn tốt của con người.                                                 0.177959
# Mèo và chó đều là thú cưng phổ biến.                                          0.058379
# Trời hôm nay rất đẹp.                                                         0.000000
# Hôm nay trời mưa.                                                             0.000000
# Tôi thích ăn cơm với cá.                                                      0.215326
# Mèo thường ăn cá.                                                             0.120603
# Chó thích chạy nhảy ngoài trời.                                               0.000000
# Trời mưa làm ướt mọi thứ.                                                     0.000000
# Cơm là món ăn truyền thống của người Việt.                                    1.000000
